# %%
lines = 5
for i in range(1, lines+1):
    for j in range(1, i+1):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
lines = 5
for i in range(lines, 0, -1):
    for j in range(1, i+1):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *
