# %% [markdown]
# https://pronto-quiz-pro.lovable.app/dashboard

# %%
print("hello world")
# Out:
# hello world

# %%
line = int(input("enter a number: "))
for i in range(1, line+1):
    for j in range(1, i+1):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
line = int(input("enter a number: "))
for i in range(line, 0, -1):
    for j in  range(1, i+1):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
lines = 9
stars = 1
space=lines-1
mid = (lines//2)
for i in range(lines):
    for k in range(space):
        print(" ",end="")
    for j in range(stars):
        print("*",end="")
    print()
    if i<mid:
        stars+=2
        space-=1
    else:
        stars-=2
        space+=1
# Out:
#         *
#        ***
#       *****
#      *******
#     *********
#      *******
#       *****
#        ***
#         *

# %%
lines = 19
stars = 1
space=lines-1
mid = (lines//2)
for i in range(lines):
    for k in range(space):
        print(" ",end="")
    for j in range(stars):
        if j==0 or j==stars-1:
            print("*",end="")
        else:
            print(" ",end="")
    print()
    if i<mid:
        stars+=2
        space-=1
    else:
        stars-=2
        space+=1
# Out:
#                   *
#                  * *
#                 *   *
#                *     *
#               *       *
#              *         *
#             *           *
#            *             *
#           *               *
#          *                 *
#           *               *
#            *             *
#             *           *
#              *         *
#               *       *
#                *     *
#                 *   *
#                  * *
#                   *

# %%
for i in range(5):
    for j in range(5):
        print("*", end = "")
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(5):
    print(5*"*")
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(5):
    for j in range(i+1):
        print("*", end = "")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(5):
    print((i+1)*"*")
# Out:
# *
# **
# ***
# ****
# *****

# %%
line = 5
for i in range(line):
    for j in range(line-i):
        print("*", end = "")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
#     *
#    **
#   ***
#  ****
# *****

line = 5
for i in range(line):
    for j in range(line-i):
        print(" ",end="")
    for k in range(i+1):
        print("*", end ="")
    print()
# Out:
#      *
#     **
#    ***
#   ****
#  *****

# %%
# *****
#  ****
#   ***
#    **
#     *
line = 5
for i in range(line):
    for j in range(i):
        print(" ",end="")
    for k in range(line-i):
        print("*", end ="")
    print()
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
#format string
a = 10
b = 20
print(f"the value of a is {a} and the value of b is {b}")
# Out:
# the value of a is 10 and the value of b is 20

# %%
list1 = "apple, banana, watermelon"
result = list1.split(",")
print(result)
# Out:
# ['apple', ' banana', ' watermelon']

# %%
string1 = "hello world"
print(len(string1))
# Out:
# 11

# %%
string1 = "hello world"
str = string1.upper()
print(str)
# Out:
# HELLO WORLD

# %%
string1 = "HELLO WORLD"
str = string1.lower()
print(str)
# Out:
# hello world

# %%
string1 = "HELLO ß WORLD"
str = string1.casefold()
print(str)
# Out:
# hello ss world

# %%
string1 = "HELLO WORLD"
str = string1.title()
print(str)
# Out:
# Hello World

# %%
string1 = "HELLO WORLD"
str = string1.capitalize()
print(str)
# Out:
# Hello world

# %%
string1 = "     HELLO WORLD"
str = string1.strip()
print(str)
# Out:
# HELLO WORLD

# %%
string1 = "HELLO WORLD"
str = string1.replace("WORLD", "PYTHON")
print(str)
# Out:
# HELLO PYTHON

# %%
string1 = "HELLO WORLD"
str = string1.find("world")
print(str)
# Out:
# -1

# %%
#startwith
st = "hello world"
print(st.startswith(("hello","python","c++")))
# Out:
# True

# %%
st = "hello world"
print(st.endswith("world"))
# Out:
# True

# %%
st = "this is a python class and topic is loops"
str = st.split()
print(str)
# Out:
# ['this', 'is', 'a', 'python', 'class', 'and', 'topic', 'is', 'loops']

# %%
st = "13124"
str = st.isdigit()
print(str)
# Out:
# True

# %%
string1 = "hello world"
print(string1.center(20))
# Out:
#     hello world

# %%
#separate string with s mean whenever there is s in the string it will separate the string into two parts and then join the string with s again
str1 = "this is a python class and topic is loops"
separator = "s"
str2 = str1.split(separator)
print(str2)
# Out:
# ['thi', ' i', ' a python cla', '', ' and topic i', ' loop', '']

# %%
str1 = "this is a python class and topic is loops"
list1 = str1.split()
print(list1)
# Out:
# ['this', 'is', 'a', 'python', 'class', 'and', 'topic', 'is', 'loops']

# %%
#use of seprotator join
str1 = "this is a python class and topic is loops"
separator = "this"
print(separator.join(str1))
# Out:
# tthishthisithissthis thisithissthis thisathis thispthisythistthishthisothisnthis thiscthislthisathissthissthis thisathisnthisdthis thistthisothispthisithiscthis thisithissthis thislthisothisothispthiss

# %%
#slice operator
str1 = "this is a python class and topic is loops"
print(str1[::-1])
# Out:
# spool si cipot dna ssalc nohtyp a si siht

# %%
s = "I want to learn Python"
result = " ".join(s.split()[:-1])
print(result)
# Out:
# I want to learn

# %%
#count in list
list1 = [1, 2, 3, 4, 5, 1, 2, 1]
print(list1.count(1))
# Out:
# 3

# %%
list1 = [1, 2, 3, 4, 5, 1, 2, 1]
list2 = [1, 2, 3]
# print(list1 + list2)
print(list1)
print(list2)
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 1, 2, 1]
# [1, 2, 3]
# [1, 2, 3, 4, 5, 1, 2, 1, 1, 2, 3]

# %%
#use extend to add list2 to list1
list1 = [1, 2, 3, 4, 5]
list2 = [1, 2, 3]
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 1, 2, 3]

# %%
list1 = [1, 2, 3, 4, 5, 11, 2, 1]
print(list1.index(11))
# Out:
# 5

# %%
list1 = [1, 2, 3, 4, 5, 1, 2, 1]
list1.insert(2, 10)
print(list1)
# Out:
# [1, 2, 10, 3, 4, 5, 1, 2, 1]

# %%
list1 = [1, 2, 3, 4, 5, 1, 2, 1]
list1.sort(reverse=True)
print(list1)
# Out:
# [5, 4, 3, 2, 2, 1, 1, 1]

# %%
#set element
set1 = {1, 2, 3, 4, 5}
set2 = {1, 2, 3}
# print(set1.intersection(set2))
set1.intersection_update(set2)
print(set1)
# Out:
# {1, 2, 3}

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {1, 2, 3, 7, 6}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {1, 2, 3, 7, 6}
set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {1, 2, 3, 7, 6}
print(set1.symmetric_difference(set2))
# Out:
# {4, 5, 6, 7}

# %%
set1 = {1, 2, 3, 4, 5}
set2 = {1, 2, 3, 7, 6}
set1.symmetric_difference_update(set2)
print(set1)
# Out:
# {4, 5, 6, 7}

# %%
set1 = {1, 2, 3, 4, 5}
set1.remove(6)
print(set1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 2
#       1 set1 = {1, 2, 3, 4, 5}
# ----> 2 set1.remove(6)
#       3 print(set1)
#
# KeyError: 6

# %%
set1 = {1, 2, 3}
set2 = {1, 2, 3, 5, 4, 6}
print(set1.issubset(set2))
# Out:
# True

# %%
for i in range(1, 10):
    if i == 5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
a = 10
b = a/0
print(b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 a = 10
# ----> 2 b = a/0
#       3 print(b)
#
# ZeroDivisionError: division by zero

# %%
a = 10+"abd"
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a = 10+"abd"
#       2 print(a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = "abc"
b = int(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = "abc"
# ----> 2 b = int(a)
#       3 print(b)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
f = open("open.txt",'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 f = open("open.txt",'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'open.txt'

# %%
list1 = [1,2,3]
print(list1[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 list1 = [1,2,3]
# ----> 2 print(list1[4])
#
# IndexError: list index out of range

# %%
print("start")

try :
    a = 10
    b = a/0
    print(b)
except Exception as e:
    print(e)
print("end")
# Out:
# start
# division by zero
# end

# %%
a = {"name":"yahs"}
print(a["nam"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 a = {"name":"yahs"}
# ----> 2 print(a["nam"])
#
# KeyError: 'nam'
